# %%
import pandas as pd

# %%
# create dataframe
data = {
    'Name':['a','b','c'],
    'Age' :[28,22,15]
}

df = pd.DataFrame(data)
df
# Out:
#   Name  Age
# 0    a   28
# 1    b   22
# 2    c   15

# %%
#read
df = pd.read_csv('datasets\data.csv')
df.head()
# Out:
#        Name  Age  Salary
# 0  mohammad   31    1000
# 1       ali   26    3000
# 2     hasan   28    2000
# 3  mohammad   31    1000
# 4       ali   26    3000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    9 non-null      object
#  1   Age     9 non-null      int64
#  2   Salary  9 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 348.0+ bytes

# %%
df.describe()
# Out:
#              Age       Salary
# count   9.000000     9.000000
# mean   28.333333  2000.000000
# std     2.179449   866.025404
# min    26.000000  1000.000000
# 25%    26.000000  1000.000000
# 50%    28.000000  2000.000000
# 75%    31.000000  3000.000000
# max    31.000000  3000.000000

# %%
df['Age']
# Out:
# 0    31
# 1    26
# 2    28
# 3    31
# 4    26
# 5    28
# 6    31
# 7    26
# 8    28
# Name: Age, dtype: int64

# %%
df.iloc[2, :]
# Out:
# Name      hasan
# Age          28
# Salary     2000
# Name: 2, dtype: object

# %%
df.iloc[2,1]
# Out:
# np.int64(28)

# %%
df.iloc[4,2]
# Out:
# np.int64(3000)

# %%
df
# Out:
#        Name  Age  Salary
# 0  mohammad   31    1000
# 1       ali   26    3000
# 2     hasan   28    2000
# 3  mohammad   31    1000
# 4       ali   26    3000
# 5     hasan   28    2000
# 6  mohammad   31    1000
# 7       ali   26    3000
# 8     hasan   28    2000

# %%
#filter
filter_df = df[df['Salary'] > 1500]
filter_df
# Out:
#     Name  Age  Salary
# 1    ali   26    3000
# 2  hasan   28    2000
# 4    ali   26    3000
# 5  hasan   28    2000
# 7    ali   26    3000
# 8  hasan   28    2000

# %%
# sort
# df_sort = df.sort_values('Salary')
# df_sort = df.sort_values('Salary', ascending=True)
df_sort = df.sort_values('Salary', ascending=False)
df_sort
# Out:
#        Name  Age  Salary
# 1       ali   26    3000
# 7       ali   26    3000
# 4       ali   26    3000
# 8     hasan   28    2000
# 2     hasan   28    2000
# 5     hasan   28    2000
# 0  mohammad   31    1000
# 3  mohammad   31    1000
# 6  mohammad   31    1000

# %%
df
# Out:
#        Name  Age  Salary
# 0  mohammad   31    1000
# 1       ali   26    3000
# 2     hasan   28    2000
# 3  mohammad   31    1000
# 4       ali   26    3000
# 5     hasan   28    2000
# 6  mohammad   31    1000
# 7       ali   26    3000
# 8     hasan   28    2000

# %%
# subset
subset = df.loc[2:4, ['Name','Age']]
subset
# Out:
#        Name  Age
# 2     hasan   28
# 3  mohammad   31
# 4       ali   26

# %%
#group
df_group = df.groupby('Age')
df_group

# %%
df
# Out:
#        Name  Age  Salary
# 0  mohammad   31    1000
# 1       ali   26    3000
# 2     hasan   28    2000
# 3  mohammad   31    1000
# 4       ali   26    3000
# 5     hasan   28    2000
# 6  mohammad   31    1000
# 7       ali   26    3000
# 8     hasan   28    2000

# %%
df_group.count()
# Out:
#      Name  Salary
# Age
# 26      3       3
# 28      3       3
# 31      3       3

# %%
# add a new column
df['test'] = [1,2,3,4,5,6,7,8,9]
df
# Out:
#        Name  Age  Salary  test
# 0  mohammad   31    1000     1
# 1       ali   26    3000     2
# 2     hasan   28    2000     3
# 3  mohammad   31    1000     4
# 4       ali   26    3000     5
# 5     hasan   28    2000     6
# 6  mohammad   31    1000     7
# 7       ali   26    3000     8
# 8     hasan   28    2000     9

# %%
#delete a column
df.drop('test', axis=1, inplace=True)

# %%
df
# Out:
#        Name  Age  Salary
# 0  mohammad   31    1000
# 1       ali   26    3000
# 2     hasan   28    2000
# 3  mohammad   31    1000
# 4       ali   26    3000
# 5     hasan   28    2000
# 6  mohammad   31    1000
# 7       ali   26    3000
# 8     hasan   28    2000

# %%
len(df)
# Out:
# 9

# %%
# add new row
df.loc[len(df)] = {
    "Name":'Test',
    "Age": 22,
}
df
# Out:
#        Name  Age  Salary
# 0  mohammad   31  1000.0
# 1       ali   26  3000.0
# 2     hasan   28  2000.0
# 3  mohammad   31  1000.0
# 4       ali   26  3000.0
# 5     hasan   28  2000.0
# 6  mohammad   31  1000.0
# 7       ali   26  3000.0
# 8     hasan   28  2000.0
# 9      Test   22     NaN

# %%
df.isna()
# Out:
#     Name    Age  Salary
# 0  False  False   False
# 1  False  False   False
# 2  False  False   False
# 3  False  False   False
# 4  False  False   False
# 5  False  False   False
# 6  False  False   False
# 7  False  False   False
# 8  False  False   False
# 9  False  False    True

# %%
df1 = df.dropna()
df1
# Out:
#        Name  Age  Salary
# 0  mohammad   31  1000.0
# 1       ali   26  3000.0
# 2     hasan   28  2000.0
# 3  mohammad   31  1000.0
# 4       ali   26  3000.0
# 5     hasan   28  2000.0
# 6  mohammad   31  1000.0
# 7       ali   26  3000.0
# 8     hasan   28  2000.0

# %%
df2 = df.fillna(0)
df2
# Out:
#        Name  Age  Salary
# 0  mohammad   31  1000.0
# 1       ali   26  3000.0
# 2     hasan   28  2000.0
# 3  mohammad   31  1000.0
# 4       ali   26  3000.0
# 5     hasan   28  2000.0
# 6  mohammad   31  1000.0
# 7       ali   26  3000.0
# 8     hasan   28  2000.0
# 9      Test   22     0.0

# %%
#write
df.to_csv('datasets/new_data.csv')
